# %% [raw]
# <h2 class="view-grouping-header ui-accordion-header ui-corner-top ui-state-default ui-accordion-icons ui-accordion-header-active ui-state-active" role="tab" id="ui-id-27" aria-controls="ui-id-28" aria-selected="true" aria-expanded="true" tabindex="0"><span class="ui-accordion-header-icon ui-icon ui-icon-triangle-1-s"></span>February 2019
# (7 meeting days)</h2>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ola.org/en/legislative-business/house-documents/parliament-42/session-1/'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
t = soup.find(class_='view-grouping-content')

# %%
type(t)
# Out:
# bs4.element.Tag

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-36ef92d7c821> in <module>
# ----> 1 t.children()
#
# TypeError: 'list_iterator' object is not callable

# %% [markdown]
# got the session lists from within the sub headings

# %%
type(session_list.children)
# Out:
# list_iterator

# %%
for x in session_list.children:
    print(type(x))
# Out:
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %%
span_class="ui-accordion-header-icon ui-icon ui-icon-triangle-1-e"

# %%
tab_list = soup.find(class_ = r"view-grouping-header ui-accordion-header ui-corner-top ui-accordion-header-collapsed ui-corner-all ui-state-default ui-accordion-icons" )

# %%
type(tab_list)
# Out:
# NoneType

# %% [markdown]
# need to use findall here and iterate through them in order to get useful text and links

# %%
session_list = soup.find_all(class_='view-grouping-content')

# %%
type(session_list)
# Out:
# bs4.element.ResultSet

# %%
type(session_list.pop())
# Out:
# bs4.element.Tag

# %%
while session_list.pop() is not None:
    s = session_list.pop()
    print(s.get_text())
# Out:
# Thursday, September 27, 2018
#
#
#
#
#
# Wednesday, September 26, 2018
#
#
#
#
#
# Tuesday, September 25, 2018
#
#
#
#
#
# Monday, September 24, 2018
#
#
#
#
#
# Thursday, September 20, 2018
#
#
#
#
#
# Wednesday, September 19, 2018
#
#
#
#
#
# Monday, September 17, 2018
#
#
#
#
#
# Saturday, September 15, 2018
#
#
#
#
#
# Thursday, September 13, 2018
#
#
#
#
#
# Wednesday, September 12, 2018
#
#
#
#
#
#
#
# Thursday, November 29, 2018
#
#
#
#
#
# Wednesday, November 28, 2018
#
#
#
#
#
# Tuesday, November 27, 2018
#
#
#
#
#
# Monday, November 26, 2018
#
#
#
#
#
# Thursday, November 22, 2018
#
#
#
#
#
# Wednesday, November 21, 2018
#
#
#
#
#
# Tuesday, November 20, 2018
#
#
#
#
#
# Monday, November 19, 2018
#
#
#
#
#
# Thursday, November 15, 2018
#
#
#
#
#
# Wednesday, November 14, 2018
#
#
#
#
#
# Tuesday, November 13, 2018
#
#
#
#
#
# Monday, November 12, 2018
#
#
#
#
#
# Thursday, November 01, 2018
#
#
#
#
#
#
#
# Thursday, February 28, 2019
#
#
#
#
#
# ...

# %%
link_list = soup.find_all(class_='field-content')

# %%
type(link_list)
# Out:
# bs4.element.ResultSet

# %%
while link_list.pop() is not None:
    x = link_list.pop()
    print(x.get_text())
# Out:
# Thursday, July 12, 2018
#
# Tuesday, July 17, 2018
#
# Thursday, July 19, 2018
#
# Tuesday, July 24, 2018
#
# Thursday, July 26, 2018
#
# Tuesday, July 31, 2018
#
# Thursday, August 02, 2018
#
# Wednesday, August 08, 2018
#
# Monday, August 13, 2018
#
# Wednesday, September 12, 2018
#
# Saturday, September 15, 2018
#
# Wednesday, September 19, 2018
#
# Monday, September 24, 2018
#
# Wednesday, September 26, 2018
#
# Monday, October 01, 2018
#
# Wednesday, October 03, 2018
#
# Monday, October 15, 2018
#
# Wednesday, October 17, 2018
#
# Monday, October 22, 2018
#
# Wednesday, October 24, 2018
#
# Monday, October 29, 2018
#
# Wednesday, October 31, 2018
#
# Monday, November 12, 2018
#
# Wednesday, November 14, 2018
#
# Monday, November 19, 2018
#
# Wednesday, November 21, 2018
#
# Monday, November 26, 2018
#
# Wednesday, November 28, 2018
#
# Monday, December 03, 2018
#
# Wednesday, December 05, 2018
#
# Monday, December 17, 2018
#
# Wednesday, December 19, 2018
#
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #main-content
# /
# /en/members
# /en/legislative-business
# /en/get-involved
# /en/visit-learn
# #off-canvas
# /fr/affaires-legislatives/documents-chambre/legislature-42/session-1
# /fr/affaires-legislatives/documents-chambre/legislature-42/session-1
# None
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-21/hansard
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-20/hansard-1
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-15/hansard-1
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-14/hansard
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-13/hansard-1
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-08/hansard-1
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-07/hansard
# /en/legislative-business/house-documents/parliament-42/session-1/2020-07-06/hansard
# ...
